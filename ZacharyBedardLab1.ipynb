# %%
# Zachary Bédard, 261113611

# %%
import math

# QUESTION 1


def naivelog(x):

    # we want to find y = log(x)

    # let n be a big power of 2
    # then, y = log(x) <=> y/(2^n) = (1/2^n)log(x), then we have :
    # y/(2^n) = log(x^(1/2^n)) this is equivalent to taking the square root of x, n times. 
    
    # since n is big, taking this much square root will give : 
    
    # x^(1/2^n) = l, l ≈ 1 (even if x is between 0 and 1, l will be close to 1, unless we have a very small or very big x compared to n)

    # let l = 1+r
    
    # y/(2^n) = log(l) = log(1 + r) 

    # the taylor serie for log(1 + r) = x - x^2/2 + x^3/3 - ... 
    
    # for very small r > 0 (and r is very small since l ≈ 1), log(1 + r) ≈ r (all the ^k terms becomes smaller and smaller) 
    # note, if we have x between 0 and 1, then r will be negative. 
    
    # y/(2^n) ≈ r
    
    # y ≈ (2^n) * r


    #This function approximate log(x) using this method, with n = 15.
    
  n=15
  y = x

    
    
  for i in range(n): # in this loop we take succesives square roots of x, which is equivalent to computing l = x^(1/2^n), n =15
    y = math.sqrt(y)

  l = y-1 # here we find r, l = 1+r <=> l-1 = r

    
  for i in range(n): # finally, we compute y, y = (2^n) * r, which is equivalent to multiplying r by 2, n times.
    l = l*2
  return l # we return y.

def mylog(x):

  # we want to find y = log(x)
  # y = log(x) <=> e^x = y
    
  # e^(x-1) = (e^x)/e = y/e

  # despite the best of my effort, I do not understand why this work, z will become smaller and smaller, and we need to 
  # compensate by multipying by 2^n.
    
    
  n=15
  z = x-1
  for i in range(n):
    z = z/(1+math.sqrt(1+z))
  l = z
  for i in range(n):
    l = l*2
  return l

# %%
import math 

#QUESTION 2 

#Compute the logarithms of the numbers 1, 2, . . . , 14 by using the functions naivelog and
#mylog, and compare the errors with Python's built-in function math.log taken as the
#"gold standard." Change the parameter n to be 15, 20, 25, 30, 35 and see what happens
#to the errors. Explain, as quantitatively as possible, why the functions naivelog and
#mylog behave differently. 


def naivelog(x,n): #input has been changed to be able to work with different n's
  #n=15
  y = x
  for i in range(n):
    y = math.sqrt(y)
  l = y-1
  for i in range(n):
    l = l*2
  return l

def mylog(x,n): #input has been changed to be able to work with different n's
  #n=15
  z = x-1
  for i in range(n):
    z = z/(1+math.sqrt(1+z))
  l = z
  for i in range(n):
    l = l*2
  return l

def question2():

    for n in (15,20,25,30,35):
    
        for a in range(1,15):
    
        
            naive_log_of_a = naivelog(a, n)
            my_log_of_a = mylog(a, n)
    
            print("absolute error of naivelog(" + str(a) + ") is: " +  str(naive_log_of_a - math.log(a)) + " with n = " + str(n))
            print("absolute error of mylog(" + str(a) + ") is:    " +  str(my_log_of_a - math.log(a)) + " with n = " + str(n))
            print("difference (naive - mylog) :" + str((naive_log_of_a - math.log(a)) - (my_log_of_a - math.log(a))))

            print("")

            
            if a != 1 :
                print("relative error of naivelog(" + str(a) + ") is: " +  (str((naive_log_of_a - math.log(a))/ math.log(a)) + " with n = " + str(n)))
                print("relative error of mylog(" + str(a) + ") is:    " +  (str((my_log_of_a - math.log(a))/ math.log(a)) + " with n = " + str(n)))
                #print("difference (naive - mylog) :" + str(((naive_log_of_a - math.log(a))/ math.log(a)) - ((my_log_of_a - math.log(a))/ math.log(a))))
            print("")

        print("_____________________________________________________")

question2()

#see the cell below for the results of running question2()

# for log(1), both algorithms give the good answer, 0, no matter what. 


# for both algorithms, the relative error seems to grow as 'a' grows, from 1.0576657730874648e-05 (naivelog(2))
# and 1.0576661194259212e-05 (mylog(2)) to respectively 4.02698992625724e-05 (naivelog(14)) and 4.0269900190612864e-05 (mylog(14)). 
# For n = 15, naivelog seems to be a little bit better. They are however really close,
# and we can even see numbers, like log(11), for wich the relative error of naivelog (3.658987086649693e-05) is 
# bigger than mylog (3.6589870679630544e-05).

# as we increase 'n' however, the error of mylog gets better and better, while the error of naivelog stagnates at best,
# for n = 35, the relative error of naivelog(2) is 2.06104397500709e-06 (bigger than with n = 15), 
# while the relative error of mylog(2) is 1.0086789203887223e-11, (a lot smaller than with n = 15). 
# This advantage is conserved with larger values : relatve error of naivelog(14) is 1.509966703333429e-06,
# relatve error of mylog(14) is 3.84048890753034e-11 (with n = 35). 

# as I have no idea how mylog(x) works, I cannot explain this difference in behavior for these functions, nor implement
# exponential, sine, cosine and arctangent functions.
# Out:
# absolute error of naivelog(1) is: 0.0 with n = 15
# absolute error of mylog(1) is:    0.0 with n = 15
# difference (naive - mylog) :0.0
#
#
# absolute error of naivelog(2) is: 7.33118048590331e-06 with n = 15
# absolute error of mylog(2) is:    7.3311828865385564e-06 with n = 15
# difference (naive - mylog) :-2.400635246146976e-12
#
# relative error of naivelog(2) is: 1.0576657730874648e-05 with n = 15
# relative error of mylog(2) is:    1.0576661194259212e-05 with n = 15
#
# absolute error of naivelog(3) is: 1.8416787324726513e-05 with n = 15
# absolute error of mylog(3) is:    1.841678542136016e-05 with n = 15
# difference (naive - mylog) :1.9033663534173684e-12
#
# relative error of naivelog(3) is: 1.676368225141e-05 with n = 15
# relative error of mylog(3) is:    1.6763680518891284e-05 with n = 15
#
# absolute error of naivelog(4) is: 2.9324936239527588e-05 with n = 15
# absolute error of mylog(4) is:    2.932493831786509e-05 with n = 15
# ...

# %%
"""
>>>question2()

absolute error of naivelog(1) is: 0.0 with n = 15
absolute error of mylog(1) is:    0.0 with n = 15
difference (naive - mylog) :0.0


absolute error of naivelog(2) is: 7.33118048590331e-06 with n = 15
absolute error of mylog(2) is:    7.3311828865385564e-06 with n = 15
difference (naive - mylog) :-2.400635246146976e-12

relative error of naivelog(2) is: 1.0576657730874648e-05 with n = 15
relative error of mylog(2) is:    1.0576661194259212e-05 with n = 15

absolute error of naivelog(3) is: 1.8416787324726513e-05 with n = 15
absolute error of mylog(3) is:    1.841678542136016e-05 with n = 15
difference (naive - mylog) :1.9033663534173684e-12

relative error of naivelog(3) is: 1.676368225141e-05 with n = 15
relative error of mylog(3) is:    1.6763680518891284e-05 with n = 15

absolute error of naivelog(4) is: 2.9324936239527588e-05 with n = 15
absolute error of mylog(4) is:    2.932493831786509e-05 with n = 15
difference (naive - mylog) :-2.078337502098293e-12

relative error of naivelog(4) is: 2.115347004357575e-05 with n = 15
relative error of mylog(4) is:    2.1153471542779354e-05 with n = 15

absolute error of naivelog(5) is: 3.9525343868307417e-05 with n = 15
absolute error of mylog(5) is:    3.952534184148426e-05 with n = 15
difference (naive - mylog) :2.0268231537556858e-12

relative error of naivelog(5) is: 2.4558476945860943e-05 with n = 15
relative error of mylog(5) is:    2.4558475686524914e-05 with n = 15

absolute error of naivelog(6) is: 4.898774022832342e-05 with n = 15
absolute error of mylog(6) is:    4.8987739738270974e-05 with n = 15
difference (naive - mylog) :4.900524430695441e-13

relative error of naivelog(6) is: 2.7340578392159324e-05 with n = 15
relative error of mylog(6) is:    2.734057811865585e-05 with n = 15

absolute error of naivelog(7) is: 5.777956026009612e-05 with n = 15
absolute error of mylog(7) is:    5.77795602978437e-05 with n = 15
difference (naive - mylog) :-3.774758283725532e-14

relative error of naivelog(7) is: 2.969282024051652e-05 with n = 15
relative error of mylog(7) is:    2.969282025991494e-05 with n = 15

absolute error of naivelog(8) is: 6.598158012716127e-05 with n = 15
absolute error of mylog(8) is:    6.598157645676395e-05 with n = 15
difference (naive - mylog) :3.6703973194107675e-12

relative error of naivelog(8) is: 3.173043281315778e-05 with n = 15
relative error of mylog(8) is:    3.173043104806978e-05 with n = 15

absolute error of naivelog(9) is: 7.366796455210434e-05 with n = 15
absolute error of mylog(9) is:    7.366796497620953e-05 with n = 15
difference (naive - mylog) :-4.241051954068098e-13

relative error of naivelog(9) is: 3.352773554054036e-05 with n = 15
relative error of mylog(9) is:    3.352773573355895e-05 with n = 15

absolute error of naivelog(10) is: 8.090243988068124e-05 with n = 15
absolute error of mylog(10) is:    8.090243987313173e-05 with n = 15
difference (naive - mylog) :7.549516567451064e-15

relative error of naivelog(10) is: 3.5135483212689434e-05 with n = 15
relative error of mylog(10) is:    3.5135483209410725e-05 with n = 15

absolute error of naivelog(11) is: 8.773867838307581e-05 with n = 15
absolute error of mylog(11) is:    8.77386779349898e-05 with n = 15
difference (naive - mylog) :4.480860127387132e-13

relative error of naivelog(11) is: 3.658987086649693e-05 with n = 15
relative error of mylog(11) is:    3.6589870679630544e-05 with n = 15

absolute error of naivelog(12) is: 9.42217558885794e-05 with n = 15
absolute error of mylog(12) is:    9.422175820050782e-05 with n = 15
difference (naive - mylog) :-2.311928426479426e-12

relative error of naivelog(12) is: 3.791762394640375e-05 with n = 15
relative error of mylog(12) is:    3.791762487679219e-05 with n = 15

absolute error of naivelog(13) is: 0.00010038965998360183 with n = 15
absolute error of mylog(13) is:    0.00010038966168623986 with n = 15
difference (naive - mylog) :-1.70263803056514e-12

relative error of naivelog(13) is: 3.9139041748159447e-05 with n = 15
relative error of mylog(13) is:    3.913904241196906e-05 with n = 15

absolute error of naivelog(14) is: 0.00010627457281175978 with n = 15
absolute error of mylog(14) is:    0.00010627457526091177 with n = 15
difference (naive - mylog) :-2.4491519923230953e-12

relative error of naivelog(14) is: 4.02698992625724e-05 with n = 15
relative error of mylog(14) is:    4.0269900190612864e-05 with n = 15

_____________________________________________________
absolute error of naivelog(1) is: 0.0 with n = 20
absolute error of mylog(1) is:    0.0 with n = 20
difference (naive - mylog) :0.0


absolute error of naivelog(2) is: 2.29147362529325e-07 with n = 20
absolute error of mylog(2) is:    2.290979003172211e-07 with n = 20
difference (naive - mylog) :4.9462212103890124e-11

relative error of naivelog(2) is: 3.3058976355384264e-07 with n = 20
relative error of mylog(2) is:    3.30518404665729e-07 with n = 20

absolute error of naivelog(3) is: 5.756008338853036e-07 with n = 20
absolute error of mylog(3) is:    5.755183134503739e-07 with n = 20
difference (naive - mylog) :8.252043492973371e-11

relative error of naivelog(3) is: 5.239344578815214e-07 with n = 20
relative error of mylog(3) is:    5.2385934454465e-07 with n = 20

absolute error of naivelog(4) is: 9.165054317694654e-07 with n = 20
absolute error of mylog(4) is:    9.163918031074303e-07 with n = 20
difference (naive - mylog) :1.1362866203512567e-10

relative error of naivelog(4) is: 6.61118920680803e-07 with n = 20
relative error of mylog(4) is:    6.610369549271926e-07 with n = 20

absolute error of naivelog(5) is: 1.2352021940831293e-06 with n = 20
absolute error of mylog(5) is:    1.2351473428484638e-06 with n = 20
difference (naive - mylog) :5.4851234665420634e-11

relative error of naivelog(5) is: 7.674742744285301e-07 with n = 20
relative error of mylog(5) is:    7.674401934402287e-07 with n = 20

absolute error of naivelog(6) is: 1.5309469740820703e-06 with n = 20
absolute error of mylog(6) is:    1.5308398371161047e-06 with n = 20
difference (naive - mylog) :1.0713696596553746e-10

relative error of naivelog(6) is: 8.544377749216803e-07 with n = 20
relative error of mylog(6) is:    8.543779806424785e-07 with n = 20

absolute error of naivelog(7) is: 1.8055674024797241e-06 with n = 20
absolute error of mylog(7) is:    1.805576634428263e-06 with n = 20
difference (naive - mylog) :-9.231948538968027e-12

relative error of naivelog(7) is: 9.278780951711867e-07 with n = 20
relative error of mylog(7) is:    9.278828394542378e-07 with n = 20

absolute error of naivelog(8) is: 2.0618413771877897e-06 with n = 20
absolute error of mylog(8) is:    2.0618820109064018e-06 with n = 20
difference (naive - mylog) :-4.063371861207088e-11

relative error of naivelog(8) is: 9.915361099894983e-07 with n = 20
relative error of mylog(8) is:    9.915556506776099e-07 with n = 20

absolute error of naivelog(9) is: 2.3020835393516847e-06 with n = 20
absolute error of mylog(9) is:    2.3020740584911437e-06 with n = 20
difference (naive - mylog) :9.480860541088987e-12

relative error of naivelog(9) is: 1.0477233702449249e-06 with n = 20
relative error of mylog(9) is:    1.0477190553193417e-06 with n = 20

absolute error of naivelog(10) is: 2.5281527671339177e-06 with n = 20
absolute error of mylog(10) is:    2.528143877800204e-06 with n = 20
difference (naive - mylog) :8.889333713568703e-12

relative error of naivelog(10) is: 1.0979627961746972e-06 with n = 20
relative error of mylog(10) is:    1.0979589355861175e-06 with n = 20

absolute error of naivelog(11) is: 2.741836476971571e-06 with n = 20
absolute error of mylog(11) is:    2.741768893699259e-06 with n = 20
difference (naive - mylog) :6.758327231182193e-11

relative error of naivelog(11) is: 1.1434346228856847e-06 with n = 20
relative error of mylog(11) is:    1.143406438472012e-06 with n = 20

absolute error of naivelog(12) is: 2.9445038207676077e-06 with n = 20
absolute error of mylog(12) is:    2.9443578433152595e-06 with n = 20
difference (naive - mylog) :1.4597745234823378e-10

relative error of naivelog(12) is: 1.1849555076923384e-06 with n = 20
relative error of mylog(12) is:    1.1848967620439413e-06 with n = 20

absolute error of naivelog(13) is: 3.1371150366332756e-06 with n = 20
absolute error of mylog(13) is:    3.13709763366532e-06 with n = 20
difference (naive - mylog) :1.7402967955604254e-11

relative error of naivelog(13) is: 1.2230709458287302e-06 with n = 20
relative error of mylog(13) is:    1.2230641609119423e-06 with n = 20

absolute error of naivelog(14) is: 3.3208712406640473e-06 with n = 20
absolute error of mylog(14) is:    3.3209941086020933e-06 with n = 20
difference (naive - mylog) :-1.2286793804605622e-10

relative error of naivelog(14) is: 1.2583550964950764e-06 with n = 20
relative error of mylog(14) is:    1.2584016540050885e-06 with n = 20

_____________________________________________________
absolute error of naivelog(1) is: 0.0 with n = 25
absolute error of mylog(1) is:    0.0 with n = 25
difference (naive - mylog) :0.0


absolute error of naivelog(2) is: 9.355234920072064e-09 with n = 25
absolute error of mylog(2) is:    7.15930781325369e-09 with n = 25
difference (naive - mylog) :2.195927106818374e-09

relative error of naivelog(2) is: 1.3496751025539225e-08 with n = 25
relative error of mylog(2) is:    1.0328697878378709e-08 with n = 25

absolute error of naivelog(3) is: 1.9834087483516782e-08 with n = 25
absolute error of mylog(3) is:    1.7984941313997638e-08 with n = 25
difference (naive - mylog) :1.8491461695191447e-09

relative error of naivelog(3) is: 1.805376445184535e-08 with n = 25
relative error of mylog(3) is:    1.6370599072582266e-08 with n = 25

absolute error of naivelog(4) is: 3.3611631033991785e-08 with n = 25
absolute error of mylog(4) is:    2.8637231475059366e-08 with n = 25
difference (naive - mylog) :4.9743995589324186e-09

relative error of naivelog(4) is: 2.4245666704464766e-08 with n = 25
relative error of mylog(4) is:    2.065739591692874e-08 with n = 25

absolute error of naivelog(5) is: 3.7521363127623886e-08 with n = 25
absolute error of mylog(5) is:    3.8598336082884543e-08 with n = 25
difference (naive - mylog) :-1.0769729552606577e-09

relative error of naivelog(5) is: 2.331333370348962e-08 with n = 25
relative error of mylog(5) is:    2.398249462416897e-08 with n = 25

absolute error of naivelog(6) is: 5.1541064305382633e-08 with n = 25
absolute error of mylog(6) is:    4.783871898617065e-08 with n = 25
difference (naive - mylog) :3.702345319211986e-09

relative error of naivelog(6) is: 2.8765615692595227e-08 with n = 25
relative error of mylog(6) is:    2.669929742678075e-08 with n = 25

absolute error of naivelog(7) is: 5.142133319147035e-08 with n = 25
absolute error of mylog(7) is:    5.64242368383816e-08 with n = 25
difference (naive - mylog) :-5.00290364691125e-09

relative error of naivelog(7) is: 2.642533788953926e-08 with n = 25
relative error of mylog(7) is:    2.899632178072253e-08 with n = 25

absolute error of naivelog(8) is: 6.531860785585764e-08 with n = 25
absolute error of mylog(8) is:    6.443377076337242e-08 with n = 25
difference (naive - mylog) :8.848370924852134e-10

relative error of naivelog(8) is: 3.1411610543805566e-08 with n = 25
relative error of mylog(8) is:    3.098609384869789e-08 with n = 25

absolute error of naivelog(9) is: 6.947049735472888e-08 with n = 25
absolute error of mylog(9) is:    7.193976570007976e-08 with n = 25
difference (naive - mylog) :-2.4692683453508835e-09

relative error of naivelog(9) is: 3.161738589277508e-08 with n = 25
relative error of mylog(9) is:    3.274119834727824e-08 with n = 25

absolute error of naivelog(10) is: 7.667892010232435e-08 with n = 25
absolute error of mylog(10) is:    7.900443943498203e-08 with n = 25
difference (naive - mylog) :-2.3255193326576773e-09

relative error of naivelog(10) is: 3.330123187873979e-08 with n = 25
relative error of mylog(10) is:    3.431119209247236e-08 with n = 25

absolute error of naivelog(11) is: 8.570449416822612e-08 with n = 25
absolute error of mylog(11) is:    8.568021359067757e-08 with n = 25
difference (naive - mylog) :2.4280577548552174e-11

relative error of naivelog(11) is: 3.574155015878071e-08 with n = 25
relative error of mylog(11) is:    3.5731424371460476e-08 with n = 25

absolute error of naivelog(12) is: 9.069862150212771e-08 with n = 25
absolute error of mylog(12) is:    9.201111428325248e-08 with n = 25
difference (naive - mylog) :-1.3124927811247744e-09

relative error of naivelog(12) is: 3.6499810369079924e-08 with n = 25
relative error of mylog(12) is:    3.702799631974199e-08 with n = 25

absolute error of naivelog(13) is: 9.541550793912279e-08 with n = 25
absolute error of mylog(13) is:    9.803422607035372e-08 with n = 25
difference (naive - mylog) :-2.618718131230935e-09

relative error of naivelog(13) is: 3.71997628965092e-08 with n = 25
relative error of mylog(13) is:    3.822072579529431e-08 with n = 25

absolute error of naivelog(14) is: 1.0548005180410769e-07 with n = 25
absolute error of mylog(14) is:    1.0378098469487895e-07 with n = 25
difference (naive - mylog) :1.6990671092287357e-09

relative error of naivelog(14) is: 3.9968836834433365e-08 with n = 25
relative error of mylog(14) is:    3.932502091949966e-08 with n = 25

_____________________________________________________
absolute error of naivelog(1) is: 0.0 with n = 30
absolute error of mylog(1) is:    0.0 with n = 30
difference (naive - mylog) :0.0


absolute error of naivelog(2) is: 1.904654323148236e-09 with n = 30
absolute error of mylog(2) is:    2.2372836916417782e-10 with n = 30
difference (naive - mylog) :1.6809259539840582e-09

relative error of naivelog(2) is: 2.747835346613685e-09 with n = 30
relative error of mylog(2) is:    3.2277180869933465e-10 with n = 30

absolute error of naivelog(3) is: -2.1858449161804572e-07 with n = 30
absolute error of mylog(3) is:    5.620293119790176e-10 with n = 30
difference (naive - mylog) :-2.1914652093002474e-07

relative error of naivelog(3) is: -1.9896417860303033e-07 with n = 30
relative error of mylog(3) is:    5.115811262773945e-10 with n = 30

absolute error of naivelog(4) is: 3.809308646296472e-09 with n = 30
absolute error of mylog(4) is:    8.949134766567113e-10 with n = 30
difference (naive - mylog) :2.9143951696397608e-09

relative error of naivelog(4) is: 2.747835346613685e-09 with n = 30
relative error of mylog(4) is:    6.455436173986693e-10 with n = 30

absolute error of naivelog(5) is: -2.0834779657086244e-07 with n = 30
absolute error of mylog(5) is:    1.2061980303457176e-09 with n = 30
difference (naive - mylog) :-2.0955399460120816e-07

relative error of naivelog(5) is: -1.2945376454799612e-07 with n = 30
relative error of mylog(5) is:    7.494529742507892e-10 with n = 30

absolute error of naivelog(6) is: 2.173874191768732e-08 with n = 30
absolute error of mylog(6) is:    1.494960377712573e-09 with n = 30
difference (naive - mylog) :2.0243781539974748e-08

relative error of naivelog(6) is: 1.2132622872116333e-08 with n = 30
relative error of mylog(6) is:    8.343532730744534e-10 with n = 30

absolute error of naivelog(7) is: -1.720960847162445e-07 with n = 30
absolute error of mylog(7) is:    1.763258206111118e-09 with n = 30
difference (naive - mylog) :-1.738593429223556e-07

relative error of naivelog(7) is: -8.843989266400224e-08 with n = 30
relative error of mylog(7) is:    9.061354692903637e-10 with n = 30

absolute error of naivelog(8) is: 5.7139630804670105e-09 with n = 30
absolute error of mylog(8) is:    2.0135546563437856e-09 with n = 30
difference (naive - mylog) :3.700408424123225e-09

relative error of naivelog(8) is: 2.7478354000041273e-09 with n = 30
relative error of mylog(8) is:    9.683151057553537e-10 with n = 30

absolute error of naivelog(9) is: -1.9875040413452894e-07 with n = 30
absolute error of mylog(9) is:    2.2481172479160705e-09 with n = 30
difference (naive - mylog) :-2.00998521382445e-07

relative error of naivelog(9) is: -9.04552070755925e-08 with n = 30
relative error of mylog(9) is:    1.023162252554789e-09 with n = 30

absolute error of naivelog(10) is: -2.0644314258078111e-07 with n = 30
absolute error of mylog(10) is:    2.468887760898042e-09 with n = 30
difference (naive - mylog) :-2.0891203034167916e-07

relative error of naivelog(10) is: -8.965711764959947e-08 with n = 30
relative error of mylog(10) is:    1.0722243309964945e-09 with n = 30

absolute error of naivelog(11) is: -1.7506582672410786e-07 with n = 30
absolute error of mylog(11) is:    2.677504440384837e-09 with n = 30
difference (naive - mylog) :-1.777433311644927e-07

relative error of naivelog(11) is: -7.300812037541743e-08 with n = 30
relative error of mylog(11) is:    1.116606079822727e-09 with n = 30

absolute error of naivelog(12) is: 2.3643396129813254e-08 with n = 30
absolute error of mylog(12) is:    2.8753497360867186e-09 with n = 30
difference (naive - mylog) :2.0768046393726536e-08

relative error of naivelog(12) is: 9.514802550763986e-09 with n = 30
relative error of mylog(12) is:    1.1571258567528197e-09 with n = 30

absolute error of naivelog(13) is: -8.339842638704908e-08 with n = 30
absolute error of mylog(13) is:    3.0635720627003593e-09 with n = 30
difference (naive - mylog) :-8.646199844974944e-08

relative error of naivelog(13) is: -3.251464834751604e-08 with n = 30
relative error of mylog(13) is:    1.1943986550020217e-09 with n = 30

absolute error of naivelog(14) is: -1.7019143028207395e-07 with n = 30
absolute error of mylog(14) is:    3.2431586305392557e-09 with n = 30
difference (naive - mylog) :-1.734345889126132e-07

relative error of naivelog(14) is: -6.448947825884697e-08 with n = 30
relative error of mylog(14) is:    1.2289079870091597e-09 with n = 30

_____________________________________________________
absolute error of naivelog(1) is: 0.0 with n = 35
absolute error of mylog(1) is:    0.0 with n = 35
difference (naive - mylog) :0.0


absolute error of naivelog(2) is: -1.4286068202862268e-06 with n = 35
absolute error of mylog(2) is:    6.991629497576923e-12 with n = 35
difference (naive - mylog) :-1.4286138119157243e-06

relative error of naivelog(2) is: -2.06104397500709e-06 with n = 35
relative error of mylog(2) is:    1.0086789203887223e-11 with n = 35

absolute error of naivelog(3) is: -2.3643517035321082e-06 with n = 35
absolute error of mylog(3) is:    1.7563728249569976e-11 with n = 35
difference (naive - mylog) :-2.3643692672603578e-06

relative error of naivelog(3) is: -2.1521256660969114e-06 with n = 35
relative error of mylog(3) is:    1.598719441857251e-11 with n = 35

absolute error of naivelog(4) is: -2.8572136405724535e-06 with n = 35
absolute error of mylog(4) is:    2.7966295945702768e-11 with n = 35
difference (naive - mylog) :-2.8572416068683992e-06

relative error of naivelog(4) is: -2.06104397500709e-06 with n = 35
relative error of mylog(4) is:    2.0173418236449254e-11 with n = 35

absolute error of naivelog(5) is: -1.8772778502818e-06 with n = 35
absolute error of mylog(5) is:    3.7694292132073315e-11 with n = 35
difference (naive - mylog) :-1.877315544573932e-06

relative error of naivelog(5) is: -1.166418310255051e-06 with n = 35
relative error of mylog(5) is:    2.3420780535152665e-11 with n = 35

absolute error of naivelog(6) is: -3.7929585237073127e-06 with n = 35
absolute error of mylog(6) is:    4.671774078701674e-11 with n = 35
difference (naive - mylog) :-3.7930052414480997e-06

relative error of naivelog(6) is: -2.1168904581491823e-06 with n = 35
relative error of mylog(6) is:    2.6073667581700672e-11 with n = 35

absolute error of naivelog(7) is: -2.5562818757318695e-06 with n = 35
absolute error of mylog(7) is:    5.5103699381220395e-11 with n = 35
difference (naive - mylog) :-2.5563369794312507e-06

relative error of naivelog(7) is: -1.3136690185684447e-06 with n = 35
relative error of mylog(7) is:    2.831769977045022e-11 with n = 35

absolute error of naivelog(8) is: -4.285820460747658e-06 with n = 35
absolute error of mylog(8) is:    6.292388832207507e-11 with n = 35
difference (naive - mylog) :-4.28588338463598e-06

relative error of naivelog(8) is: -2.0610439749536997e-06 with n = 35
relative error of mylog(8) is:    3.025999387856956e-11 with n = 35

absolute error of naivelog(9) is: -4.7287034070642164e-06 with n = 35
absolute error of mylog(9) is:    7.02540248198602e-11 with n = 35
difference (naive - mylog) :-4.728773661089036e-06

relative error of naivelog(9) is: -2.1521256660969114e-06 with n = 35
relative error of mylog(9) is:    3.197398460972609e-11 with n = 35

absolute error of naivelog(10) is: -3.3058846709010936e-06 with n = 35
absolute error of mylog(10) is:    7.715250660567108e-11 with n = 35
difference (naive - mylog) :-3.3059618234076993e-06

relative error of naivelog(10) is: -1.4357274703808925e-06 with n = 35
relative error of mylog(10) is:    3.350690788384713e-11 with n = 35

absolute error of naivelog(11) is: -7.08920462066942e-06 with n = 35
absolute error of mylog(11) is:    8.366951576022075e-11 with n = 35
difference (naive - mylog) :-7.089288290185181e-06

relative error of naivelog(11) is: -2.956427956253585e-06 with n = 35
relative error of mylog(11) is:    3.4892898246793524e-11 with n = 35

absolute error of naivelog(12) is: -5.221565344104562e-06 with n = 35
absolute error of mylog(12) is:    8.985701072106167e-11 with n = 35
difference (naive - mylog) :-5.221655201115283e-06

relative error of naivelog(12) is: -2.1013124756819493e-06 with n = 35
relative error of mylog(12) is:    3.616112127541202e-11 with n = 35

absolute error of naivelog(13) is: -3.218170054886116e-07 with n = 35
absolute error of mylog(13) is:    9.573986048394545e-11 with n = 35
difference (naive - mylog) :-3.2191274534909553e-07

relative error of naivelog(13) is: -1.2546719667288302e-07 with n = 35
relative error of mylog(13) is:    3.7326218627059634e-11 with n = 35

absolute error of naivelog(14) is: -3.984888695907074e-06 with n = 35
absolute error of mylog(14) is:    1.0135270400724039e-10 with n = 35
difference (naive - mylog) :-3.984990048611081e-06

relative error of naivelog(14) is: -1.509966703333429e-06 with n = 35
relative error of mylog(14) is:    3.84048890753034e-11 with n = 35

# %%
# Question 3
# Question 4

# %%
# PART 2

#QUESTION 1 : 

def my_tan(x) :

    # I was not able to implement my_tan(x) using the CORDIC algorithm, however, I
    # would like to use it for question 2, so I do this :
    return math.tan(x)
    


#QUESTION 2 : 


def my_sin(x) :

   

    while (x > 2 * math.pi) :
        x = x - 2 * math.pi

    while ( x < - 2 * math.pi) :
        x = x - 2 * math.pi

    if x == 0 : 
        return 0

    sin_x = abs(my_tan(x)/(math.sqrt( 1 + (my_tan(x) ** 2))))

    if x < 0 and x < - math.pi or x > 0 and x > math.pi : 
        sin_x = - sin_x

    return sin_x


def my_cos(x) :

   

    while (x > 2 * math.pi) :
        x = x - 2 * math.pi

    while ( x < - 2 * math.pi) :
        x = x - 2 * math.pi

    if x == 0 :
         return 1

    cos_x = abs( (1 /my_tan(x))/(math.sqrt( 1 + (1/my_tan(x)) ** 2)))

    if (x > math.pi/2 and x < 3 * (math.pi/2)) or (x < -3 * (math.pi/2) and x > - math.pi/2) :

     
        cos_x = - cos_x

    return cos_x



# QUESTION 3

def my_arctan(x) :
    # I was not able to implement my_arctan(x) using the CORDIC algorithm, however, I
    # would like to use it for question 4, so I do this :

    return math.atan(x)

# QUESTION 4


def my_arcsin(x) :

    return (my_arctan(x/math.sqrt(1 - x ** 2)))
    
print(my_arcsin(-0.52))

# I am sorry for this very bad homework, I lost too much time trying to understand mylog(x) 
# and there was no time left to complete it properly.
# Out:
# -0.546850950695944
